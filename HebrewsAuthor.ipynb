# %% [markdown]
# This project is for author fingerprinting. It is the continuation of the not-so-good (https://www.kaggle.com/code/hjaimes/nltk-used-for-author-fingerprinting)
#
# The intention remains the same: Who is the author of the book of Hebrews?, was it the Apostle Paul? or was it Apostle Luke?. While some belive it was Apostle Paul, this is still uncertain to this time.
#
# Since the book of Hebrews is relatively short, one may use lines of these and other books that we know were written by Apostle Paul. Sometimes it is pretty straight forward knowing the author as some books start like: "Paul, a servant of Jesus Christ..." or something similar. Then we would gather books written by Apostle Luke, with this we can train our model and feed it with "Hebrews" for prediction. Let's see what would be the results.
#
# In this second attempt I will use scikit-learn approach, but in the future I would use spaCy (https://spacy.io/) to close the truth gap, the bible version to be used need to be in actual language, as the American Standard Version or the World English Version (https://worldenglish.bible/), The later will be used. The King James version cannot be used, even it is the most popular, it is a form of old english and spaCy might not be optimized for it.

# %%
# Some interesting libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn import metrics

# Useful definitions
FILE = 'WEB.txt' # Name of the bible version to analyze (World English version)

# Useful functions
# Print lines of a portion
def print_lines(bible_lines, start, stop):
    for i in range(start, stop):
        print(bible_lines[i])
        
# Filter unwanted characters, punctuation, etc., from lines, just alphanumeric and spaces
def filter_line(line):
    line_fltd = [] # list
    for word in line.split(): # list
        word_fltd = ''
        for char in word: # str
            if char.isalnum(): # is alphanumeric character
                word_fltd += char
        line_fltd.append(word_fltd)
    line_fltd = ' '.join(line_fltd).lower() # list to str
    return line_fltd
        
# Retrieve a full book dictionary
def retrieve_book(book_name, bible_lines):
    book_dict = {'bible_lines_indexes': [], 'references': [], 'lines': [], 'lines_fltd': []}
    for i in range(len(bible_lines)):
        if book_name in bible_lines[i].split('\t')[0]:
            book_dict['bible_lines_indexes'].append(i)
            book_dict['references'].append(bible_lines[i].split('\t')[0])
            book_dict['lines'].append(bible_lines[i].split('\t')[1])
            book_dict['lines_fltd'].append(filter_line(bible_lines[i].split('\t')[1]))
    return book_dict

# Prepare dictionary of the book for model training
def add_book_author(book_dict, book_author):
    book_df = pd.DataFrame(book_dict)
    book_df['author'] = book_author
    return book_df.to_dict('list')

# %%
# Read the full bible
with open(FILE, 'r', encoding='utf-8') as corpus:
    bible_lines = corpus.readlines()

# %%
# Retrieve the book of interest and add book author
hebrews = add_book_author(retrieve_book('Hebrews', bible_lines), 'Unknown')

# Convert to Dataframe
hebrews_df = pd.DataFrame(hebrews)

hebrews_df.head()
# Out:
#    bible_lines_indexes   references  \
# 0                29966  Hebrews 1:1
# 1                29967  Hebrews 1:2
# 2                29968  Hebrews 1:3
# 3                29969  Hebrews 1:4
# 4                29970  Hebrews 1:5
#
#                                                lines  \
# 0  God, having in the past spoken to the fathers ...
# 1  has at the end of these days spoken to us by h...
# 2  His Son is the radiance of his glory, the very...
# 3  having become so much better than the angels, ...
# 4  For to which of the angels did he say at any t...
#
#                                           lines_fltd   author
# 0  god having in the past spoken to the fathers t...  Unknown
# 1  has at the end of these days spoken to us by h...  Unknown
# 2  his son is the radiance of his glory the very ...  Unknown
# 3  having become so much better than the angels a...  Unknown
# 4  for to which of the angels did he say at any t...  Unknown

# %%
# Retrieve the book of interest and add book author
romans = add_book_author(retrieve_book('Romans', bible_lines), 'Paul')

# Convert to Dataframe
romans_df = pd.DataFrame(romans)

romans_df.head()
# Out:
#    bible_lines_indexes  references  \
# 0                27933  Romans 1:1
# 1                27934  Romans 1:2
# 2                27935  Romans 1:3
# 3                27936  Romans 1:4
# 4                27937  Romans 1:5
#
#                                                lines  \
# 0  Paul, a servant of Jesus Christ, called to be ...
# 1  which he promised before through his prophets ...
# 2  concerning his Son, who was born of the seed o...
# 3  who was declared to be the Son of God with pow...
# 4  through whom we received grace and apostleship...
#
#                                           lines_fltd author
# 0  paul a servant of jesus christ called to be an...   Paul
# 1  which he promised before through his prophets ...   Paul
# 2  concerning his son who was born of the seed of...   Paul
# 3  who was declared to be the son of god with pow...   Paul
# 4  through whom we received grace and apostleship...   Paul

# %%
# Retrieve the book of interest and add book author
ephesians = add_book_author(retrieve_book('Ephesians', bible_lines), 'Paul')

# Convert to Dataframe
ephesians_df = pd.DataFrame(ephesians)

ephesians_df.head()
# Out:
#    bible_lines_indexes     references  \
# 0                29209  Ephesians 1:1
# 1                29210  Ephesians 1:2
# 2                29211  Ephesians 1:3
# 3                29212  Ephesians 1:4
# 4                29213  Ephesians 1:5
#
#                                                lines  \
# 0  Paul, an apostle of Christ Jesus through the w...
# 1  Grace to you and peace from God our Father and...
# 2  Blessed be the God and Father of our Lord Jesu...
# 3  even as he chose us in him before the foundati...
# 4  having predestined us for adoption as children...
#
#                                           lines_fltd author
# 0  paul an apostle of christ jesus through the wi...   Paul
# 1  grace to you and peace from god our father and...   Paul
# 2  blessed be the god and father of our lord jesu...   Paul
# 3  even as he chose us in him before the foundati...   Paul
# 4  having predestined us for adoption as children...   Paul

# %%
# Retrieve the book of interest and add book author
galatians = add_book_author(retrieve_book('Galatians', bible_lines), 'Paul')

# Convert to Dataframe
galatians_df = pd.DataFrame(galatians)

galatians_df.head()
# Out:
#    bible_lines_indexes     references  \
# 0                29060  Galatians 1:1
# 1                29061  Galatians 1:2
# 2                29062  Galatians 1:3
# 3                29063  Galatians 1:4
# 4                29064  Galatians 1:5
#
#                                                lines  \
# 0  Paul, an apostle (not from men, neither throug...
# 1  and all the brothers who are with me, to the a...
# 2  Grace to you and peace from God the Father, an...
# 3  who gave himself for our sins, that he might d...
# 4     to whom be the glory forever and ever. Amen.\n
#
#                                           lines_fltd author
# 0  paul an apostle not from men neither through m...   Paul
# 1  and all the brothers who are with me to the as...   Paul
# 2  grace to you and peace from god the father and...   Paul
# 3  who gave himself for our sins that he might de...   Paul
# 4         to whom be the glory forever and ever amen   Paul

# %%
# Retrieve the book of interest and add book author
corinthians_1 = add_book_author(retrieve_book('1 Corinthians', bible_lines), 'Paul')

# Convert to Dataframe
corinthians_1_df = pd.DataFrame(corinthians_1)

corinthians_1_df.head()
# Out:
#    bible_lines_indexes         references  \
# 0                28366  1 Corinthians 1:1
# 1                28367  1 Corinthians 1:2
# 2                28368  1 Corinthians 1:3
# 3                28369  1 Corinthians 1:4
# 4                28370  1 Corinthians 1:5
#
#                                                lines  \
# 0  Paul, called to be an apostle of Jesus Christ ...
# 1  to the assembly of God which is at Corinth; th...
# 2  Grace to you and peace from God our Father and...
# 3  I always thank my God concerning you, for the ...
# 4  that in everything you were enriched in him, i...
#
#                                           lines_fltd author
# 0  paul called to be an apostle of jesus christ t...   Paul
# 1  to the assembly of god which is at corinth tho...   Paul
# 2  grace to you and peace from god our father and...   Paul
# 3  i always thank my god concerning you for the g...   Paul
# 4  that in everything you were enriched in him in...   Paul

# %%
# Retrieve the book of interest and add book author
corinthians_2 = add_book_author(retrieve_book('2 Corinthians', bible_lines), 'Paul')

# Convert to Dataframe
corinthians_2_df = pd.DataFrame(corinthians_2)

corinthians_2_df.head()
# Out:
#    bible_lines_indexes         references  \
# 0                28803  2 Corinthians 1:1
# 1                28804  2 Corinthians 1:2
# 2                28805  2 Corinthians 1:3
# 3                28806  2 Corinthians 1:4
# 4                28807  2 Corinthians 1:5
#
#                                                lines  \
# 0  Paul, an apostle of Christ Jesus through the w...
# 1  Grace to you and peace from God our Father and...
# 2  Blessed be the God and Father of our Lord Jesu...
# 3  who comforts us in all our affliction, that we...
# 4  For as the sufferings of Christ abound to us, ...
#
#                                           lines_fltd author
# 0  paul an apostle of christ jesus through the wi...   Paul
# 1  grace to you and peace from god our father and...   Paul
# 2  blessed be the god and father of our lord jesu...   Paul
# 3  who comforts us in all our affliction that we ...   Paul
# 4  for as the sufferings of christ abound to us e...   Paul

# %%
# Retrieve the book of interest and add book author
colossians = add_book_author(retrieve_book('Colossians', bible_lines), 'Paul')

# Convert to Dataframe
colossians_df = pd.DataFrame(colossians)

colossians_df.head()
# Out:
#    bible_lines_indexes      references  \
# 0                29468  Colossians 1:1
# 1                29469  Colossians 1:2
# 2                29470  Colossians 1:3
# 3                29471  Colossians 1:4
# 4                29472  Colossians 1:5
#
#                                                lines  \
# 0  Paul, an apostle of Christ Jesus through the w...
# 1  to the saints and faithful brothers in Christ ...
# 2  We give thanks to God the Father of our Lord J...
# 3  having heard of your faith in Christ Jesus, an...
# 4  because of the hope which is laid up for you i...
#
#                                           lines_fltd author
# 0  paul an apostle of christ jesus through the wi...   Paul
# 1  to the saints and faithful brothers in christ ...   Paul
# 2  we give thanks to god the father of our lord j...   Paul
# 3  having heard of your faith in christ jesus and...   Paul
# 4  because of the hope which is laid up for you i...   Paul

# %%
# Retrieve the book of interest and add book author
philippians = add_book_author(retrieve_book('Philippians', bible_lines), 'Paul') # Paul & Timothy

# Convert to Dataframe
philippians_df = pd.DataFrame(philippians)

philippians_df.head()
# Out:
#    bible_lines_indexes       references  \
# 0                29364  Philippians 1:1
# 1                29365  Philippians 1:2
# 2                29366  Philippians 1:3
# 3                29367  Philippians 1:4
# 4                29368  Philippians 1:5
#
#                                                lines  \
# 0  Paul and Timothy, servants of Jesus Christ; To...
# 1  Grace to you, and peace from God, our Father, ...
# 2          I thank my God whenever I remember you,\n
# 3  always in every request of mine on behalf of y...
# 4  for your partnership in furtherance of the Goo...
#
#                                           lines_fltd author
# 0  paul and timothy servants of jesus christ to a...   Paul
# 1  grace to you and peace from god our father and...   Paul
# 2             i thank my god whenever i remember you   Paul
# 3  always in every request of mine on behalf of y...   Paul
# 4  for your partnership in furtherance of the goo...   Paul

# %%
# Retrieve the book of interest and add book author
thessalonians = add_book_author(retrieve_book('Thessalonians', bible_lines), 'Paul') # Paul, Silvanus & Timothy

# Convert to Dataframe
thessalonians_df = pd.DataFrame(thessalonians)

thessalonians_df.head()
# Out:
#    bible_lines_indexes           references  \
# 0                29563  1 Thessalonians 1:1
# 1                29564  1 Thessalonians 1:2
# 2                29565  1 Thessalonians 1:3
# 3                29566  1 Thessalonians 1:4
# 4                29567  1 Thessalonians 1:5
#
#                                                lines  \
# 0  Paul, Silvanus, and Timothy, to the assembly o...
# 1  We always give thanks to God for all of you, m...
# 2  remembering without ceasing your work of faith...
# 3  We know, brothers loved by God, that you are c...
# 4  and that our Good News came to you not in word...
#
#                                           lines_fltd author
# 0  paul silvanus and timothy to the assembly of t...   Paul
# 1  we always give thanks to god for all of you me...   Paul
# 2  remembering without ceasing your work of faith...   Paul
# 3  we know brothers loved by god that you are chosen   Paul
# 4  and that our good news came to you not in word...   Paul

# %%
# Retrieve the book of interest and add book author
timothy_1 = add_book_author(retrieve_book('1 Timothy', bible_lines), 'Paul') 

# Convert to Dataframe
timothy_1_df = pd.DataFrame(timothy_1)

timothy_1_df.head()
# Out:
#    bible_lines_indexes     references  \
# 0                29699  1 Timothy 1:1
# 1                29700  1 Timothy 1:2
# 2                29701  1 Timothy 1:3
# 3                29702  1 Timothy 1:4
# 4                29703  1 Timothy 1:5
#
#                                                lines  \
# 0  Paul, an apostle of Christ Jesus according to ...
# 1  to Timothy, my true child in faith: Grace, mer...
# 2  As I urged you when I was going into Macedonia...
# 3  neither to pay attention to myths and endless ...
# 4  but the goal of this command is love, out of a...
#
#                                           lines_fltd author
# 0  paul an apostle of christ jesus according to t...   Paul
# 1  to timothy my true child in faith grace mercy ...   Paul
# 2  as i urged you when i was going into macedonia...   Paul
# 3  neither to pay attention to myths and endless ...   Paul
# 4  but the goal of this command is love out of a ...   Paul

# %%
# Retrieve the book of interest and add book author
timothy_2 = add_book_author(retrieve_book('2 Timothy', bible_lines), 'Paul')

# Convert to Dataframe
timothy_2_df = pd.DataFrame(timothy_2)

timothy_2_df.head()
# Out:
#    bible_lines_indexes     references  \
# 0                29812  2 Timothy 1:1
# 1                29813  2 Timothy 1:2
# 2                29814  2 Timothy 1:3
# 3                29815  2 Timothy 1:4
# 4                29816  2 Timothy 1:5
#
#                                                lines  \
# 0  Paul, an apostle of Jesus Christ through the w...
# 1  to Timothy, my beloved child: Grace, mercy, an...
# 2  I thank God, whom I serve as my forefathers di...
# 3  longing to see you, remembering your tears, th...
# 4  having been reminded of the sincere faith that...
#
#                                           lines_fltd author
# 0  paul an apostle of jesus christ through the wi...   Paul
# 1  to timothy my beloved child grace mercy and pe...   Paul
# 2  i thank god whom i serve as my forefathers did...   Paul
# 3  longing to see you remembering your tears that...   Paul
# 4  having been reminded of the sincere faith that...   Paul

# %%
# Retrieve the book of interest and add book author
titus = add_book_author(retrieve_book('Titus', bible_lines), 'Paul')

# Convert to Dataframe
titus_df = pd.DataFrame(titus)

titus_df.head()
# Out:
#    bible_lines_indexes references  \
# 0                29895  Titus 1:1
# 1                29896  Titus 1:2
# 2                29897  Titus 1:3
# 3                29898  Titus 1:4
# 4                29899  Titus 1:5
#
#                                                lines  \
# 0  Paul, a servant of God, and an apostle of Jesu...
# 1  in hope of eternal life, which God, who can’t ...
# 2  but in his own time revealed his word in the m...
# 3  to Titus, my true child according to a common ...
# 4  I left you in Crete for this reason, that you ...
#
#                                           lines_fltd author
# 0  paul a servant of god and an apostle of jesus ...   Paul
# 1  in hope of eternal life which god who cant lie...   Paul
# 2  but in his own time revealed his word in the m...   Paul
# 3  to titus my true child according to a common f...   Paul
# 4  i left you in crete for this reason that you w...   Paul

# %%
# Retrieve the book of interest and add book author
philemon = add_book_author(retrieve_book('Philemon', bible_lines), 'Paul') # Paul & Timothy

# Convert to Dataframe
philemon_df = pd.DataFrame(philemon)

philemon_df.head()
# Out:
#    bible_lines_indexes    references  \
# 0                29941  Philemon 1:1
# 1                29942  Philemon 1:2
# 2                29943  Philemon 1:3
# 3                29944  Philemon 1:4
# 4                29945  Philemon 1:5
#
#                                                lines  \
# 0  Paul, a prisoner of Christ Jesus, and Timothy ...
# 1  to the beloved Apphia, to Archippus, our fello...
# 2  Grace to you and peace from God our Father and...
# 3  I thank my God always, making mention of you i...
# 4  hearing of your love, and of the faith which y...
#
#                                           lines_fltd author
# 0  paul a prisoner of christ jesus and timothy ou...   Paul
# 1  to the beloved apphia to archippus our fellow ...   Paul
# 2  grace to you and peace from god our father and...   Paul
# 3  i thank my god always making mention of you in...   Paul
# 4  hearing of your love and of the faith which yo...   Paul

# %%
# Retrieve the book of interest and add book author
luke = add_book_author(retrieve_book('Luke', bible_lines), 'Luke')

# Convert to Dataframe
luke_df = pd.DataFrame(luke)

luke_df.head()
# Out:
#    bible_lines_indexes references  \
# 0                24896   Luke 1:1
# 1                24897   Luke 1:2
# 2                24898   Luke 1:3
# 3                24899   Luke 1:4
# 4                24900   Luke 1:5
#
#                                                lines  \
# 0  Since many have undertaken to set in order a n...
# 1  even as those who from the beginning were eyew...
# 2  it seemed good to me also, having traced the c...
# 3  that you might know the certainty concerning t...
# 4  There was in the days of Herod, the king of Ju...
#
#                                           lines_fltd author
# 0  since many have undertaken to set in order a n...   Luke
# 1  even as those who from the beginning were eyew...   Luke
# 2  it seemed good to me also having traced the co...   Luke
# 3  that you might know the certainty concerning t...   Luke
# 4  there was in the days of herod the king of jud...   Luke

# %%
# Retrieve the book of interest and add book author
acts = add_book_author(retrieve_book('Acts', bible_lines), 'Luke')

# Convert to Dataframe
acts_df = pd.DataFrame(acts)

acts_df.head()
# Out:
#    bible_lines_indexes references  \
# 0                26926   Acts 1:1
# 1                26927   Acts 1:2
# 2                26928   Acts 1:3
# 3                26929   Acts 1:4
# 4                26930   Acts 1:5
#
#                                                lines  \
# 0  The first book I wrote, Theophilus, concerned ...
# 1  until the day in which he was received up, aft...
# 2  To these he also showed himself alive after he...
# 3  Being assembled together with them, he command...
# 4  For John indeed baptized in water, but you wil...
#
#                                           lines_fltd author
# 0  the first book i wrote theophilus concerned al...   Luke
# 1  until the day in which he was received up afte...   Luke
# 2  to these he also showed himself alive after he...   Luke
# 3  being assembled together with them he commande...   Luke
# 4  for john indeed baptized in water but you will...   Luke

# %%
# Let's try Luke and Paul
# Paul: romans_df, luke_df, ephesians_df, corinthians_1_df, corinthians_2_df, colossians_df, galatians_df, philippians_df, thessalonians_df, timothy_1_df, timothy_2_df, titus_df,
#       philemon_df (& Timothy)
# Luke: luke_df, acts_df

# Classificator Dataframe
luke_paul_df = pd.concat([romans_df, luke_df, ephesians_df, corinthians_1_df, corinthians_2_df, colossians_df, galatians_df, philippians_df, thessalonians_df, timothy_1_df, timothy_2_df, titus_df,\
                          philemon_df, acts_df])

# %%
# Let's see how balanced is the data to avoid bias as much as possible
luke_paul_df['author'].value_counts()
# Out:
# Luke    2158
# Paul    2033
# Name: author, dtype: int64

# %%
# Yep, just two values for classification
luke_paul_df['author'].unique()
# Out:
# array(['Paul', 'Luke'], dtype=object)

# %%
# So far so good as no null information
luke_paul_df.isnull().sum()
# Out:
# bible_lines_indexes    0
# references             0
# lines                  0
# lines_fltd             0
# author                 0
# dtype: int64

# %%
# Train and evaluate the models
X = luke_paul_df['lines_fltd']
y = luke_paul_df['author']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=5)

# %%
# Naïve Bayes:
text_clf_mnb = Pipeline([('tfidf', TfidfVectorizer()),
                     ('clf', MultinomialNB()),])

# Train the model 
text_clf_mnb.fit(X_train, y_train)

# Form a prediction set
predictions = text_clf_mnb.predict(X_test)

# Print confusion matrix
print(metrics.confusion_matrix(y_test,predictions))

# Print a classification report
print(metrics.classification_report(y_test,predictions))

# Print the overall accuracy
print(metrics.accuracy_score(y_test,predictions))
# Out:
# [[495  48]
#  [ 61 444]]
#               precision    recall  f1-score   support
#
#         Luke       0.89      0.91      0.90       543
#         Paul       0.90      0.88      0.89       505
#
#     accuracy                           0.90      1048
#    macro avg       0.90      0.90      0.90      1048
# weighted avg       0.90      0.90      0.90      1048
#
# 0.8959923664122137

# %%
# Linear SVC:
text_clf_lsvc = Pipeline([('tfidf', TfidfVectorizer()),
                     ('clf', LinearSVC()),])

# Train the model 
text_clf_lsvc.fit(X_train, y_train)

# Form a prediction set
predictions = text_clf_lsvc.predict(X_test)

# Print confusion matrix
print(metrics.confusion_matrix(y_test,predictions))

# Print a classification report
print(metrics.classification_report(y_test,predictions))

# Print the overall accuracy
print(metrics.accuracy_score(y_test,predictions))
# Out:
# [[496  47]
#  [ 63 442]]
#               precision    recall  f1-score   support
#
#         Luke       0.89      0.91      0.90       543
#         Paul       0.90      0.88      0.89       505
#
#     accuracy                           0.90      1048
#    macro avg       0.90      0.89      0.89      1048
# weighted avg       0.90      0.90      0.89      1048
#
# 0.8950381679389313
# c:\Users\Hevin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(

# %%
# I guess 90% of accuracy and F1-score for both Multinomial NB and SVC are acceptable, let's see which one would be the author of "Hebrews"
hebrews_pred = {'references': [], 'lines': [], 'MNB pred': [], 'SVC pred': []}
for i in range(len(hebrews_df['lines'])):
    hebrews_pred['references'].append(hebrews_df['references'][i])
    hebrews_pred['lines'].append(hebrews_df['lines'][i])
    hebrews_pred['MNB pred'].append(text_clf_mnb.predict([hebrews_df['lines'][i]])[0])
    hebrews_pred['SVC pred'].append(text_clf_lsvc.predict([hebrews_df['lines'][i]])[0])

hebrews_pred_df = pd.DataFrame(hebrews_pred)

# %%
hebrews_pred_df.head()
# Out:
#     references                                              lines MNB pred  \
# 0  Hebrews 1:1  God, having in the past spoken to the fathers ...     Luke
# 1  Hebrews 1:2  has at the end of these days spoken to us by h...     Luke
# 2  Hebrews 1:3  His Son is the radiance of his glory, the very...     Luke
# 3  Hebrews 1:4  having become so much better than the angels, ...     Paul
# 4  Hebrews 1:5  For to which of the angels did he say at any t...     Luke
#
#   SVC pred
# 0     Luke
# 1     Luke
# 2     Luke
# 3     Luke
# 4     Luke

# %%
hebrews_pred_df.tail()
# Out:
#         references                                              lines  \
# 298  Hebrews 13:21  make you complete in every good work to do his...
# 299  Hebrews 13:22  But I exhort you, brothers, endure the word of...
# 300  Hebrews 13:23  Know that our brother Timothy has been freed, ...
# 301  Hebrews 13:24  Greet all of your leaders and all the saints. ...
# 302  Hebrews 13:25                     Grace be with you all. Amen.\n
#
#     MNB pred SVC pred
# 298     Paul     Paul
# 299     Paul     Paul
# 300     Paul     Paul
# 301     Paul     Paul
# 302     Paul     Paul

# %%
# Let's see how the models agree on each other
hebrews_pred_df[['MNB pred', 'SVC pred']].value_counts()/len(hebrews_pred_df)*100
# Out:
# MNB pred  SVC pred
# Paul      Paul        50.495050
# Luke      Luke        33.993399
# Paul      Luke         8.250825
# Luke      Paul         7.260726
# dtype: float64

# %% [markdown]
# It is hard to interpret the truth from here, as even both models agree on 50.5% that the book of "Hebrews" was written by Paul, both of them also predict 34.% of it was written by Luke. On the other side, they disagree in 15.5% of the book giving opposite authoring. Perhaps there are other contrubitors to the book!.

# %%
# Let's see what MNB Model 'thinks'...
hebrews_pred_df['MNB pred'].value_counts()/len(hebrews_pred_df)*100
# Out:
# Paul    58.745875
# Luke    41.254125
# Name: MNB pred, dtype: float64

# %%
# Let's see what SVC Model 'thinks'...
hebrews_pred_df['SVC pred'].value_counts()/len(hebrews_pred_df)*100
# Out:
# Paul    57.755776
# Luke    42.244224
# Name: SVC pred, dtype: float64

# %% [markdown]
# Interesting enough, as per the data, it seems both Paul and Luke had written the book of "Hebrews". And may be others in minor proportion (Apostle Timothy?). The thing is that Apostle Luke and Apostle Timothy visited Apostle Paul in jail. In the next attempt I will try to use spaCy (https://spacy.io/) to uncover this conundrum sometime in the future.
